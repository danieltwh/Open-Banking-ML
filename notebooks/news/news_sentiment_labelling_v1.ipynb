# %%
import sys, os

import math

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import nltk

# from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# # If you face errors with vader sentiment analysis, run the below code
# nltk.download('vader_lexicon')

# %%
df = pd.read_csv("../../data/raw/news/newsapiorg_v2.csv", index_col=0)

# %%
df
# Out:
#                                                   title           publishedAt  \
# 1     Key remarks from Russian c.bank governor after...  2022-02-11T12:26:00Z
# 2     LIVE MARKETS Forex: worrying about an inverted...  2022-02-18T12:33:00Z
# 3     Dollar takes a break from this week's slide ah...  2022-02-03T02:18:00Z
# 4     Euro bounce pauses ahead of U.S. inflation - R...  2022-02-08T01:16:00Z
# 5     Dollar near two-week high amid jitters over ha...  2022-01-25T01:52:00Z
# ...                                                 ...                   ...
# 2171  Is First Trust Mid Cap Growth AlphaDEX ETF (FN...  2022-02-28T11:20:07Z
# 2172  Should First Trust Mid Cap Growth AlphaDEX ETF...  2022-02-15T11:20:08Z
# 2173  Should iShares Morningstar SmallCap Growth ETF...  2022-02-28T11:20:09Z
# 2174  Comcast vs. DISH Network: Which Stock is a Bet...  2022-03-02T20:28:25Z
# 2175  Is Invesco S&P 500 Equal Weight Utilities ETF ...  2022-02-25T11:20:08Z
#
#                                                     url  \
# 1     https://www.reuters.com/markets/currencies/key...
# 2     https://www.reuters.com/markets/stocks/live-ma...
# 3     https://www.reuters.com/markets/europe/dollar-...
# 4     https://www.reuters.com/business/euro-bounce-p...
# 5     https://www.reuters.com/markets/europe/dollar-...
# ...                                                 ...
# 2171  http://www.zacks.com/stock/news/1874180/is-fir...
# 2172  http://www.zacks.com/stock/news/1867522/should...
# 2173  http://www.zacks.com/stock/news/1874172/should...
# 2174  https://stocknews.com/news/cmcsa-dish-comcast-...
# 2175  http://www.zacks.com/stock/news/1873162/is-inv...
#
#                                                 content
# 1     MOSCOW, Feb 11 (Reuters) - The Russian Central...
# 2     Feb 18 - Welcome to the home for real-time cov...
# 3     SINGAPORE, Feb 3 (Reuters) - The dollar found ...
# 4     SINGAPORE, Feb 8 (Reuters) - A resurgent euro ...
# 5     TOKYO, Jan 25 (Reuters) - The safe-haven U.S. ...
# ...                                                 ...
# 2171  A smart beta exchange traded fund, the First T...
# 2172  If you're interested in broad exposure to the ...
# 2173  Launched on 06/28/2004, the iShares Morningsta...
# 2174  With more people choosing to cut the cord, cab...
# 2175  Launched on 11/01/2006, the Invesco S&amp;P 50...
#
# [2175 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# title           2
# publishedAt     0
# url             0
# content        20
# dtype: int64

# %%
df_clean = df.dropna()

# %%
analyzer = SentimentIntensityAnalyzer()
analyzer.polarity_scores("Bitcoin bounces off six month lows as buyers step in - Reuters")
# Out:
# {'neg': 0.153, 'neu': 0.847, 'pos': 0.0, 'compound': -0.2023}

# %%
def get_vader_sentiment(df, col):
    analyzer = SentimentIntensityAnalyzer()

    vader_neg = []
    vader_neu = []
    vader_pos = []
    vader_comp = []
    vader_label = []

    result_df = df.copy()

    for idx, row in df.iterrows():
        # print(idx)
        result = analyzer.polarity_scores(row[col])
        if result["compound"] >=0.05:
            curr_label = 1
        elif result["compound"] <= -0.05:
            curr_label = -1
        else:
            curr_label = 0

        vader_neg.append(result["neg"])
        vader_neu.append(result["neu"])
        vader_pos.append(result["pos"])
        vader_comp.append(result["compound"])
        vader_label.append(curr_label)

    result_df["vader_neg"] = vader_neg
    result_df["vader_neu"] = vader_neu
    result_df["vader_pos"] = vader_pos
    result_df["vader_comp"] = vader_comp
    result_df["vader_label"] = vader_label
    return result_df

# %%
final_df = get_vader_sentiment(df_clean, "title")

# %%
final_df
# Out:
#                                                   title           publishedAt  \
# 1     Key remarks from Russian c.bank governor after...  2022-02-11T12:26:00Z
# 2     LIVE MARKETS Forex: worrying about an inverted...  2022-02-18T12:33:00Z
# 3     Dollar takes a break from this week's slide ah...  2022-02-03T02:18:00Z
# 4     Euro bounce pauses ahead of U.S. inflation - R...  2022-02-08T01:16:00Z
# 5     Dollar near two-week high amid jitters over ha...  2022-01-25T01:52:00Z
# ...                                                 ...                   ...
# 2171  Is First Trust Mid Cap Growth AlphaDEX ETF (FN...  2022-02-28T11:20:07Z
# 2172  Should First Trust Mid Cap Growth AlphaDEX ETF...  2022-02-15T11:20:08Z
# 2173  Should iShares Morningstar SmallCap Growth ETF...  2022-02-28T11:20:09Z
# 2174  Comcast vs. DISH Network: Which Stock is a Bet...  2022-03-02T20:28:25Z
# 2175  Is Invesco S&P 500 Equal Weight Utilities ETF ...  2022-02-25T11:20:08Z
#
#                                                     url  \
# 1     https://www.reuters.com/markets/currencies/key...
# 2     https://www.reuters.com/markets/stocks/live-ma...
# 3     https://www.reuters.com/markets/europe/dollar-...
# 4     https://www.reuters.com/business/euro-bounce-p...
# 5     https://www.reuters.com/markets/europe/dollar-...
# ...                                                 ...
# 2171  http://www.zacks.com/stock/news/1874180/is-fir...
# 2172  http://www.zacks.com/stock/news/1867522/should...
# 2173  http://www.zacks.com/stock/news/1874172/should...
# 2174  https://stocknews.com/news/cmcsa-dish-comcast-...
# 2175  http://www.zacks.com/stock/news/1873162/is-inv...
#
#                                                 content  vader_neg  vader_neu  \
# 1     MOSCOW, Feb 11 (Reuters) - The Russian Central...      0.000      1.000
# 2     Feb 18 - Welcome to the home for real-time cov...      0.211      0.789
# 3     SINGAPORE, Feb 3 (Reuters) - The dollar found ...      0.000      1.000
# 4     SINGAPORE, Feb 8 (Reuters) - A resurgent euro ...      0.000      1.000
# 5     TOKYO, Jan 25 (Reuters) - The safe-haven U.S. ...      0.197      0.803
# ...                                                 ...        ...        ...
# 2171  A smart beta exchange traded fund, the First T...      0.000      0.521
# 2172  If you're interested in broad exposure to the ...      0.000      0.670
# 2173  Launched on 06/28/2004, the iShares Morningsta...      0.000      0.809
# 2174  With more people choosing to cut the cord, cab...      0.000      0.734
# 2175  Launched on 11/01/2006, the Invesco S&amp;P 50...      0.000      0.784
#
#       vader_pos  vader_comp  vader_label
# 1         0.000      0.0000            0
# 2         0.000     -0.3400           -1
# 3         0.000      0.0000            0
# 4         0.000      0.0000            0
# 5         0.000     -0.4019           -1
# ...         ...         ...          ...
# 2171      0.479      0.8481            1
# 2172      0.330      0.7096            1
# 2173      0.191      0.3818            1
# 2174      0.266      0.4404            1
# 2175      0.216      0.5106            1
#
# [2153 rows x 9 columns]

# %% [markdown]
# ## Export of labelled dataset

# %%
# Export the labelled dataset
final_df.to_excel("../../data/raw/news/newsapiorg_labelling_v2.xlsx")
